# %% [markdown]
# ## El comando SSH
# SSH - secure shell
# Puedes pensarlo como una manera de accedder a otra computadora
#
# Ejemplo de conneción:
# ssh - directory/key.pem user@ipaddress

# %% [markdown]
# ## Corriendo linux en un contenedor
# https://github.com/nickjj/docker-django-example
#
# git clone https://github.com/nickjj/docker-django-example hellodjango
#
# cd hellodjango
#
# cp .env.example .env
#
# docker compose up --build
#
# docker exec -it hellodjango-web-1 bash
#
# cat /etc/issue

# %% [markdown]
# ## Principales carpetas en linux

# %%
from IPython.display import Image
display.Image(filename="Downloads/3u7dC.jpg")

# %% [markdown]
# ## Comandos esenciales
# pwd - print working directory - imprime la ruta del directorio en el que estamos
#
# ls - list - lista los archivos y carpetas en el directorio en el que estamos
#
# ed - chango directory - cambiar de directorio/carpeta (usar .. para carpeta anterior/padre)
#
# clear - limpiar la terminal
#
# mkdir - make directory - crear una carpeta
#
# touch - create files - crear archivos
#
# cp - copy -copiar
#
# mv - move mover o renombrar
#
# rm - remove - eliminar (usar -r para eliminar carpetas)

# %% [markdown]
# ## Introducción a Django
#
# ¿Qué es Django?
# - "Web framework for perfectionist with deadlines"
# - Motiva el desarrollo rápido de sitios web de forma limpia y estructurada
# - Es usado por Instagram, YouTube, Spotify y muchas otras Empresas
#
# ¿Por qué lo necesitamos?
# - Con HTML, CSS, JS podemos crear sitios web estáticos (Frontend)
# - Pero además queremos crear comportamientos a la medida haciendo uso de bases de datos (Backend)
# - Django nos ayuda a cubrir todo esto

# %% [markdown]
# ## Proyecto y Aplicación
#
# pip freeze (para saber todas las depedencias preinstaladas en python)
#
# amqp==5.1.1
#
# asgiref==3.5.2
#
# async-timeout==4.0.2
#
# billiard==3.6.4.0
#
# black==22.10.0
#
# celery==5.2.7
#
# click==8.1.3
#
# click-didyoumean==0.3.0
#
# click-plugins==1.1.1
#
# click-repl==0.2.0
#
# Django==4.1.4 flake8==6.0.0
#
# gunicorn==20.1.0
#
# 1SOrt==5.10.1
#
# kombu==5.2.4
#
# mccabe==0.7.0
#
# mypy-extensions==0.4.3
#
# pathspec==0.10.3
#
# platformdirs==2.6.0
#
# prompt-toolkit==3.0.36
#
# psycopg2==2.9.5
#
# pycodestyle==2.10.0
#
# pyflakes==3.0.1
#
# pytz==2022.6 redis==4.4.0
#
# six==1.16.0
#
# sqlparse==0.4.3
#
# vine==5.0.0
#
# wcwidth==0.2.5
#
# whitenoise==6.2.0

# %% [markdown]
# ## Migraciones
#
#
# (Los cambios a la base de datos, base de datos es donde almacenamos la información)
#
# En este proyecto:
#
# •/run manage migrate
#
# En Django standard:
#
# python manage-py migrate
#
# Ver el sitio web: http://localhost: 8000/

# %% [markdown]
# # Estructura de un Proyecto en Django
#
# ## Archivos de Proyecto
#
# • manage.py: es un archivo que contiene muchas funciones que te permiten interactuar con Django
#
# • config/init.py: un archivo vacío que le informa a Python que este directorio/carpeta debería ser considerado como un paquete de Python
#
# • config/settings.py: Configuración o ajustes para el proyecto en django
#
# • config/urls.py: las declaraciones de los urls para el proyecto django. Es como una tabla de contenidos con los endpoints del sitio web
#
# • config/asgi.py: un punto de entrada para servidores web compatibles con ASGI para desplegar el proyecto
#
# • config/wsgi.py: un punto de entrada para servidores web compatibles con WSGl para desplegar el proyecto

# %% [markdown]
# ## Archivos de Aplicación
# • admin.py: registrar tus modelos relacionados con el django admin
#
# • apps.py: contiene el código de la configuración de la app
#
# • models.py: define tus modelos aquí. Son las tablas en la base de datos para almacenar la información y definir sus relaciones
#
# • tests.py: escribir tests para la app
#
# • views.py: definir la información que será mandada a los templates del frontend

# %% [markdown]
# ## Haz tus primeros cambios visibles en el proyecto

# %%
import os

from django import get_version
from django.conf import settings
from django.shortcuts import render


def home(request):
    context = {
        "debug": settings.DEBUG,
        "django_ver": get_version() + "PROBANDO",
        "python_ver": os.environ["PYTHON_VERSION"] + "MAS CAMBIOS",
    }

    return render(request, "pages/home.html", context)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 3
#       1 import os
# ----> 3 from django import get_version
#       4 from django.conf import settings
#       5 from django.shortcuts import render
#
# ModuleNotFoundError: No module named 'django'

# %% [markdown]
# ## como nota importante usar
# # docker compose down este para detener el docker ps ya qeu este levanta un servidor gastando
# # recursos de tu equipo estos se llaman contenedores
# # preocura usar el comando para detener los contenedores
